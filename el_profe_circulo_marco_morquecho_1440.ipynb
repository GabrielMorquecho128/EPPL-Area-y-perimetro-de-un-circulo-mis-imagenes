# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMorquecho128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/el_profe_circulo_marco_morquecho_1440.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### marco morquecho NL = 39 fecha 25/marzo/2026 ❤
# ---
# # calcular area y perimetro de circulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/GabrielMorquecho128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/circulo-area-perimetro%2011.PNG)
# ---
#
# # formula para calcular el circulo
# $A=\pi*r^2$
# ---
# ## formula para calcular perimetro
# $P=2*\pi*r$
# ---
# # Datos de entrada
# $r$ ?
# ---
# ## diagrama de flujo en lucidChart
# ![Logo de Markdown](https://raw.githubusercontent.com/GabrielMorquecho128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20perimetro%20circulo.png)

# %%
# calcular area y perimetro de un circulo
# variables A, P, r
#formulas A = pi*r^2  yt P = 2 * pi * r
# captura el valor de r
import math
print("calcular area y perimetro de un circulo")
r = float(input("ingrese el valor de r: "))
A = math.pi*r**2
P = 2*math.pi*r
print("el area del circulo es: ", A)
print("el perimetro del circulo es: ", P)
print("marco morquecho NL 39")
# Out:
# calcular area y perimetro de un circulo
# ingrese el valor de r: 5
# el area del circulo es:  78.53981633974483
# el perimetro del circulo es:  31.41592653589793
# marco morquecho NL 39

# %% [markdown]
# # realacion entre codigo y DF en tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/GabrielMorquecho128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/Tldraw%20DF%20y%20codigo.png)
